# %% [markdown]
# #              UberRide FarePrice Prediction

# %% [markdown]
# # Importing Important Library

# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import gc
import os
import sys
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split as tts
# %matplotlib inline

# %% [markdown]
# # Importing DataSet from Kaggle

# %%
cab_data=pd.read_csv('cab_rides.csv')     #download csv file of data from kaggle
weather_data=pd.read_csv('weather.csv')  #download csv file of data from kaggle
cab_data
#weather_data
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %% [markdown]
# # Adding datetime column to Dataset

# %%
cab_data['datetime']=pd.to_datetime(cab_data['time_stamp'])
weather_data['datetime']=pd.to_datetime(weather_data['time_stamp'])
cab_data
#weather_data
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %% [markdown]
# # Describing the data set

# %%
cab_data.describe()
# Out:
#             distance    time_stamp          price  surge_multiplier
# count  693071.000000  6.930710e+05  637976.000000     693071.000000
# mean        2.189430  1.544046e+12      16.545125          1.013870
# std         1.138937  6.891925e+08       9.324359          0.091641
# min         0.020000  1.543204e+12       2.500000          1.000000
# 25%         1.280000  1.543444e+12       9.000000          1.000000
# 50%         2.160000  1.543737e+12      13.500000          1.000000
# 75%         2.920000  1.544828e+12      22.500000          1.000000
# max         7.860000  1.545161e+12      97.500000          3.000000

# %%
weather_data.describe()
# Out:
#               temp       clouds     pressure        rain    time_stamp  \
# count  6276.000000  6276.000000  6276.000000  894.000000  6.276000e+03
# mean     39.090475     0.677777  1008.445209    0.057652  1.543857e+09
# std       6.022055     0.314284    12.870775    0.100758  6.659340e+05
# min      19.620000     0.000000   988.250000    0.000200  1.543204e+09
# 25%      36.077500     0.440000   997.747500    0.004900  1.543387e+09
# 50%      40.130000     0.780000  1007.660000    0.014850  1.543514e+09
# 75%      42.832500     0.970000  1018.480000    0.060925  1.544691e+09
# max      55.410000     1.000000  1035.120000    0.780700  1.545159e+09
#
#           humidity         wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# max       0.990000    18.180000

# %% [markdown]
# # Concatenating both Dataset

# %%
c=pd.concat([cab_data,weather_data])
c
# Out:
#       distance cab_type     time_stamp    destination            source  \
# 0         0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1         0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2         0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3         0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4         0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...        ...      ...            ...            ...               ...
# 6271       NaN      NaN     1543819974            NaN               NaN
# 6272       NaN      NaN     1543819974            NaN               NaN
# 6273       NaN      NaN     1543819974            NaN               NaN
# 6274       NaN      NaN     1543819974            NaN               NaN
# 6275       NaN      NaN     1543819974            NaN               NaN
#
#       price  surge_multiplier                                    id  \
# ...

# %% [markdown]
# # Checking Null Values in dataset

# %%
c.isnull().sum()
# Out:
# distance              6276
# cab_type              6276
# time_stamp               0
# destination           6276
# source                6276
# price                61371
# surge_multiplier      6276
# id                    6276
# product_id            6276
# name                  6276
# datetime                 0
# temp                693071
# location            693071
# clouds              693071
# pressure            693071
# rain                698453
# humidity            693071
# wind                693071
# dtype: int64

# %% [markdown]
# # Filling all Null values

# %%
c.fillna(0, inplace=True)

# %% [markdown]
# # ReCheck for Null Values in dataset

# %%
c.isnull().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# datetime            0
# temp                0
# location            0
# clouds              0
# pressure            0
# rain                0
# humidity            0
# wind                0
# dtype: int64

# %% [markdown]
# # Converting datetime into days and hours

# %%
c['day']=c.datetime.dt.day
c['hour']=c.datetime.dt.hour
c
# Out:
#       distance cab_type     time_stamp    destination            source  \
# 0         0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1         0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2         0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3         0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4         0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...        ...      ...            ...            ...               ...
# 6271      0.00        0     1543819974              0                 0
# 6272      0.00        0     1543819974              0                 0
# 6273      0.00        0     1543819974              0                 0
# 6274      0.00        0     1543819974              0                 0
# 6275      0.00        0     1543819974              0                 0
#
#       price  surge_multiplier                                    id  \
# ...

# %% [markdown]
# # Grouping the Dataset on the basis of Cab type

# %%
c.groupby('cab_type').count()
# Out:
#           distance  time_stamp  destination  source   price  surge_multiplier  \
# cab_type
# 0             6276        6276         6276    6276    6276              6276
# Lyft        307408      307408       307408  307408  307408            307408
# Uber        385663      385663       385663  385663  385663            385663
#
#               id  product_id    name  datetime    temp  location  clouds  \
# cab_type
# 0           6276        6276    6276      6276    6276      6276    6276
# Lyft      307408      307408  307408    307408  307408    307408  307408
# Uber      385663      385663  385663    385663  385663    385663  385663
#
#           pressure    rain  humidity    wind     day    hour
# cab_type
# 0             6276    6276      6276    6276    6276    6276
# Lyft        307408  307408    307408  307408  307408  307408
# Uber        385663  385663    385663  385663  385663  385663

# %% [markdown]
# # Plotting its bar graphs

# %%
c.groupby('cab_type').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='cab_type'>

# %%
c['price'].value_counts().plot(kind='bar', figsize=(100,50), color='blue')
# Out:
# <AxesSubplot:>

# %%
c['hour'].value_counts().plot(kind='bar', figsize=(10,5), color='blue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking how price is dependent on Rain

# %%
x=c['rain']
y=c['price']
plt.plot(x,y, color='red')
plt.show()

# %% [markdown]
# # Training and Testing of Dataset

# %%
x1=a[['distance','time_stamp','surge_multiplier','temp','clouds', 'pressure','wind','rain','humidity','day','hour']]
y1=c['price']
xtrain, xtest, ytrain, ytest=tts(x1, y1, test_size=0.25, random_state=42)

# %% [markdown]
# # Code for LinearRegression

# %%
linear=LinearRegression()
linear.fit(xtrain,ytrain)
ypred=linear.predict(xtest)
ypred
# Out:
# array([32.53931144, 14.74635333, 16.82343405, ..., 11.8352222 ,
#        11.86052921, 13.22152047])

# %% [markdown]
# # Printing the actual and preicted price

# %%
df= pd.DataFrame ({'Actual':ytest, 'Predicted':ypred})
df.head(25)
# Out:
#         Actual  Predicted
# 81607     42.5  32.539311
# 354        0.0  14.746353
# 471801    32.5  16.823434
# 407645    27.5  10.471232
# 474760    27.5  10.562531
# 172711    16.5  15.471764
# 135585     7.0  13.704852
# 627286    10.5  12.735742
# 89207      7.0  11.347006
# 220521    42.5  39.354041
# 664240    19.5  17.052530
# 480941    26.0  12.444845
# 174693     7.0  13.285626
# 54739     13.5  20.691977
# 521491    11.0  17.151028
# 410197    27.5  17.306764
# 245688    26.0  13.131277
# 367806    10.5  15.576173
# 201105    15.0  12.723763
# 658150    10.5  11.655285
# 597279     7.0  11.938771
# 190363    13.0  14.821669
# 456047    17.5  16.962562
# 538886    16.0  12.432615
# 643288    11.5  16.972806

# %% [markdown]
# # Visualising the actual and preicted price on bar graph

# %%
df1=df.head(25)
df1.plot(kind='bar', figsize=(26,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
